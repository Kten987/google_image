= "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ2KtmVFMtvPmuGyq33FjLNId1IESpOCsc_6HUMMpEtX7WpWtsSe24H4VH1nmw&s"
response = requests.get(url)

with open("image.jpg", "wb") as f:
    f.write(response.content)

# %%
with open('t.htm', 'r', encoding='utf-8') as file:
    soup = file.read()

# %%
from bs4 import BeautifulSoup
import re

# %%
soup
# Out:
# '<!DOCTYPE html>\n<html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="vi">\n    <head>\n        <meta charset="utf-8" />\n        <meta content="origin" name="referrer" />\n        <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image" />\n        <title>9 Wishes Amazing Pine Ampule Serum - Tìm trên Google</title>\n        <script nonce="K0bd0F0BHytCmSIKXCQP6g">\n            (function () {\n                var b = window.addEventListener;\n                window.addEventListener = function (a, c, d) {\n                    a !== "unload" && b(a, c, d);\n                };\n            }.call(this));\n            (function () {\n                var _g = { kEI: "7XO8Zs73HZHK0-kP_YeZ4Ak", kEXPI: "31", kBL: "1R7-", kOPI: 89978449 };\n                (function () {\n                    var a;\n                    ((a = window.google) == null ? 0 : a.stvsc) ? (google.kEI = _g.kEI) : (window.google = _g);\n                }.call(this
# ...

# %%
body = soup.find('body')

# %%
body
# Out:
# 39969

# %%
text = '''
                                                1,
                                                [
                                                    0,
                                                    "hNWTX7gDx19p1M",
                                                    ["https://encrypted-tbn0.gstatic.com/images?q\u003dtbn:ANd9GcQkCrb-FhvWrHLGZgCjZFbO1keMhAw0q6vNGg\u0026s", 223, 226],
                                                    ["https://bizweb.dktcdn.net/thumb/1024x1024/100/382/633/products/9-wishes-amazing-pine-ampule-serum-25ml.png?v\u003d1642755804413", 698, 706],
                                                    null,
                                                    2,
                                                    "rgb(233,236,220)",
                                                    null,
                                                    0,
                                                    {
                                                        "2000": [null, "maycosmetic.com.vn", "78KB"],
                                                        "2001": [null, null, null, 9, 6, 21, 21],
                                                        "2003": [
                                                            null,
                                                            "F84baQWeUqZanM",
                                                            "https://maycosmetic.com.vn/9-wishes-amazing-pine-ampule-serum-25ml",
                                                            "Tinh Chất 9Wishes Thanh Lọc, Cấp Ẩm \u0026 Phục Hồi Da 25ml Amazing Pine Ampule  Serum",

                                                            "https://www.google.com/search/about-this-image?img\u003dH4sIAAAAAAAA_wEXAOj_ChUIl5zvyNbAp6mmARCEq8_8hffA418d8xKBFwAAAA%3D%3D\u0026q\u003dhttps://maycosmetic.com.vn/9-wishes-amazing-pine-ampule-serum-25ml\u0026ctx\u003div\u0026hl\u003dvi-VN",
                                                            { "26": [null, 2] },
                                                        ],
                                                        "2006": [
                                                            null,
                                                            [
                                                                "Tinh Chất 9Wishes Thanh Lọc, Cấp Ẩm \u0026 Phục Hồi Da 25ml Amazing Pine Ampule  Serum",
                                                                "Tên sản phẩm: 9 Wishes Amazing Pine Ampule Serum 25ml Giới thiệu: Tinh Chất  9Wishes Ampule Serum 25ml là dòng serum dưỡng da đến từ thương hiệu mỹ ...",
                                                                "VND",
                                                            ],
                                                        ],
                                                        "2008": [null, "Tinh Chất 9Wishes Thanh Lọc, Cấp Ẩm \u0026 Phục Hồi Da 25ml Amazing Pine Ampule  Serum May Cosmetic"],
                                                    },
                                                ],
                                                "hNWTX7gDx19p1M",
                                            ]
                        '''

match = re.search(r'"hNWTX7gDx19p1M",\s+\[([^]]+)\],\s+\[([^]]+)\]', text)
if match:
    values = match.group(2)
    result = values.split(',')[0].replace('"', '')
    print(result)
# Out:
# https://bizweb.dktcdn.net/thumb/1024x1024/100/382/633/products/9-wishes-amazing-pine-ampule-serum-25ml.png?v=1642755804413
